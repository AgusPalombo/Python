# %%
"This is a coding cell"
# Out:
# 'This is a coding cell'

# %%
num_a = 2
num_b = 3
result = 3 + 2
print(result)
# Out:
# 5

# %%
class Persona:
  def __init__(self,nombre,edad,direccion):
    self.nombre = nombre
    self.edad = edad
    self.direccion = direccion

  def saludar(self):
    print(f"Hola, mi nombre es {self.nombre}.")

  def mostrar_informacion(self):
    print(f"Nombre: {self.nombre}")
    print(f"Edad: {self.edad}")
    print(f"Direccion: {self.direccion}")

  def actualizar_edad(self, nueva_edad):
    if nueva_edad > self.edad:
      self.edad = nueva_edad
      print(f"La edad de {self.nombre} ha sido actualizada a {self.edad} años.")
    else:
      print("La nueva edad debe ser mayor que la actual")

  def cambiar_direccion(self, nueva_direccion):
    self.direccion = nueva_direccion
    print(f"{self.nombre} se ha mudado a {self.direccion}.")


persona1 = Persona("Ana",25,"Calle Falsa 123")
persona1.saludar()
persona1.mostrar_informacion()
persona1.actualizar_edad(26)
persona1.cambiar_direccion("Avenida Siempre Viva 742")
persona1.mostrar_informacion()
# Out:
# Hola, mi nombre es Ana.
# Nombre: Ana
# Edad: 25
# Direccion: Calle Falsa 123
# La edad de Ana ha sido actualizada a 26 años.
# Ana se ha mudado a Avenida Siempre Viva 742.
# Nombre: Ana
# Edad: 26
# Direccion: Avenida Siempre Viva 742

# %%
import random

# Lista de posibles títulos de empleos en Data Science
job_titles = [
    "Data Scientist",
    "Data Analyst",
    "Machine Learning Engineer",
    "Data Engineer",
    "Business Intelligence Analyst",
    "Data Architect",
    "Research Scientist",
    "Statistician",
    "Quantitative Analyst",
    "Big Data Engineer",
    "Data Visualization Specialist",
    "Analytics Consultant"
]

# Generar una lista de 100 títulos de empleo (los títulos pueden repetirse)
job_titles_100 = random.choices(job_titles, k=100)

print(job_titles_100)
# Out:
# ['Analytics Consultant', 'Data Architect', 'Research Scientist', 'Data Architect', 'Data Architect', 'Data Visualization Specialist', 'Data Architect', 'Statistician', 'Analytics Consultant', 'Data Analyst', 'Analytics Consultant', 'Data Engineer', 'Business Intelligence Analyst', 'Analytics Consultant', 'Research Scientist', 'Data Engineer', 'Data Architect', 'Analytics Consultant', 'Data Architect', 'Quantitative Analyst', 'Quantitative Analyst', 'Data Analyst', 'Research Scientist', 'Business Intelligence Analyst', 'Machine Learning Engineer', 'Research Scientist', 'Data Visualization Specialist', 'Research Scientist', 'Research Scientist', 'Research Scientist', 'Statistician', 'Business Intelligence Analyst', 'Data Architect', 'Data Architect', 'Data Visualization Specialist', 'Research Scientist', 'Data Visualization Specialist', 'Data Engineer', 'Data Scientist', 'Data Architect', 'Analytics Consultant', 'Data Architect', 'Research Scientist', 'Data Analyst', 'Data Scientist', 
# ...

# %%
# My skills
my_skills = ['Python', 'SQL', 'Excel']

# Define data science job roles and required skills
job_roles = [
    {'role': 'Data Analyst', 'skills': ['Python', 'SQL', 'Excel']},
    {'role': 'Data Scientist', 'skills': ['Python', 'R', 'Machine Learning', 'Deep Learning']},
    {'role': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn']},
    {'role': 'Data Engineer', 'skills': ['Python', 'Apache Spark', 'Hadoop', 'SQL']},
    {'role': 'Business Intelligence Analyst', 'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel']},
    {'role': 'Quantitative Analyst', 'skills': ['R', 'Python', 'MATLAB', 'Statistics']},
    {'role': 'Operations Analyst', 'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement']},
    {'role': 'Database Administrator', 'skills': ['SQL', 'Oracle', 'MySQL', 'Database Management']},
    {'role': 'AI Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision']},
    {'role': 'Statistician', 'skills': ['R', 'SAS', 'Python', 'Statistical Modeling']}
]

qualified_roles = []

for job in job_roles:
  qualified = True

  for skill in my_skills:
    if skill not in job['skills']:
      qualified = False
      break
  if qualified:
    qualified_roles.append(job['role'])

# %% [markdown]
# Esta es otra forma de implementar el codigo de arriba. Se debe utilizar ALL function

# %%
qualified_roles=[]

for job in job_roles:
  if all(skill in job['skills'] for skill in my_skills):
    qualified_roles.append(job['role'])

qualified_roles
# Out:
# ['Data Analyst', 'Business Intelligence Analyst']

# %%
qualified_roles = [job['role'] for job in job_roles if all(skill in job['skills'] for skill in my_skills)]

qualified_roles
# Out:
# ['Data Analyst', 'Business Intelligence Analyst']

# %% [markdown]
# **Functions**

# %%
def saludar(nombre):
    """Función que saluda a la persona indicada."""
    return f"Hola, {nombre}!"

# Uso:
print(saludar("Ana"))
# Out:
# Hola, Ana!

# %% [markdown]
# Lambda

# %%
# Función lambda para multiplicar dos números
multiplicar = lambda x, y: x * y

# Uso:
print(multiplicar(3, 4))  # Salida: 12
# Out:
# 12

# %% [markdown]
# Integradas

# %%
lista = [10, 20, 30, 40]
print("Longitud de la lista:", len(lista))
print("Valor máximo:", max(lista))
# Out:
# Longitud de la lista: 4
# Valor máximo: 40

# %% [markdown]
# Recursiva

# %%
def factorial(n):
    """Calcula el factorial de n de forma recursiva."""
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)

# Uso:
print("Factorial de 5:", factorial(5))  # Salida: 120
# Out:
# Factorial de 5: 120

# %% [markdown]
# Data Cleaning Excercise

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'}
]

# %% [markdown]
# Datetime

# %%
from datetime import datetime, date

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 2, 18, 3, 21, 21, 552531)

# %%
test_date = data_science_jobs[0]['job_date']

# %%
print(datetime.strptime(test_date, '%Y-%m-%d'))
# Out:
# 2023-05-12 00:00:00

# %%
import ast

for job in data_science_jobs:
  job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')
  job['job_skills'] = ast.literal_eval(job['job_skills'])

# %%
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'SQL', 'Machine Learning'],
#   'job_date': datetime.datetime(2023, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Deep Learning'],
#   'job_date': datetime.datetime(2023, 5, 15, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': ['SQL', 'R', 'Tableau'],
#   'job_date': datetime.datetime(2023, 5, 10, 0, 0)},
#  {'job_title': 'Business Intelligence Developer',
#   'job_skills': ['SQL', 'PowerBI', 'Data Warehousing'],
#   'job_date': datetime.datetime(2023, 5, 8, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': ['Python', 'Spark', 'Hadoop'],
#   'job_date': datetime.datetime(2023, 5, 18, 0, 0)},
#  {'job_title': 'AI Specialist',
#   'job_skills': ['Python', 'PyTorch', 'AI Ethics'],
#   'job_date': datetime.datetime(2023, 5, 20, 0, 0)}]

# %% [markdown]
# Abrir un archivo

# %%
file = open('Ruta del archivo/archivo.tipoArchivo')
content = file.read()
file.close()

# %% [markdown]
# **Now, what if we want to get this data into something usable (like a dictionary) to actually start performing data analysis:**

# %%
import csv

data_dict = {}
for index, row in enumerate(csv.reader(content.strip().split('\n'))):
    if index == 0:
        # Initialize dictionary with column headers as keys
        for column in row:
            data_dict[column] = []
    else:
        # Append each element in the row to the correct list in the dictionary
        for col_index, value in enumerate(row):
            data_dict[list(data_dict.keys())[col_index]].append(value)

# Print the dictionary to verify contents
print(data_dict)

# %%
# !pip install pandas

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            1.4.0
# accelerate                         1.3.0
# aiohappyeyeballs                   2.4.6
# aiohttp                            3.11.12
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.23
# albumentations                     2.0.4
# ale-py                             0.10.1
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.6.0
# arviz                              0.20.0
# astropy                            7.0.1
# astropy-iers-data                  0.2025.2.10.0.33.26
# astunparse                         1.6.3
# atpublic                           4.1.0
# ...

# %%
# !pip install pyjokes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 1.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# **NumPy**

# %%
import random

salary_list = [random.randint(50000, 100000)for _ in range(1_000_000)]

# %%
salary_list
# Out:
# [51569,
#  68168,
#  86149,
#  75634,
#  89442,
#  80056,
#  99593,
#  74571,
#  70336,
#  55230,
#  88067,
#  86605,
#  61319,
#  80823,
#  83436,
#  88788,
#  75393,
#  95771,
#  92738,
#  58578,
#  77313,
#  56326,
#  72651,
#  74505,
#  72273,
#  86646,
#  92352,
#  82999,
#  57655,
#  90549,
#  97198,
#  60537,
#  93502,
#  75760,
#  82041,
#  56711,
#  89401,
#  94526,
#  52864,
#  94007,
#  66373,
#  93478,
#  79689,
#  59366,
#  88815,
#  53022,
#  94751,
#  87078,
#  58605,
#  56391,
#  71995,
#  51781,
#  61593,
#  71465,
#  95302,
#  80643,
#  60106,
#  57821,
#  74300,
#  63846,
#  67488,
#  93127,
#  67624,
#  80389,
#  82059,
#  56819,
#  75398,
#  52769,
#  99861,
#  68614,
#  81471,
#  95800,
#  83552,
#  96007,
#  73664,
#  63542,
#  79691,
#  55559,
#  51725,
#  91984,
#  74113,
#  65961,
#  63292,
#  81465,
#  79164,
#  53427,
#  53008,
#  97732,
#  94388,
#  71490,
#  88358,
#  86452,
#  52097,
#  70436,
#  55978,
#  50444,
#  63597,
#  74338,
#  59990,
#  93622,
# ...

# %%
import numpy as np

# %%
# %%timeit

np.mean(salary_list)
# Out:
# 54.6 ms ± 5.69 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
my_array = np.array([1,2,3,4])

# %%
my_array.mean()
# Out:
# 2.5

# %% [markdown]
# **Pandas**

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Dos formas de llamar **columnas**

# %%
df['total_bedrooms']
# Out:
# 0        661.0
# 1        310.0
# 2        507.0
# 3         15.0
# 4        244.0
#          ...
# 2995     642.0
# 2996    1082.0
# 2997     201.0
# 2998      14.0
# 2999     263.0
# Name: total_bedrooms, Length: 3000, dtype: float64

# %%
df.total_bedrooms
# Out:
# 0        661.0
# 1        310.0
# 2        507.0
# 3         15.0
# 4        244.0
#          ...
# 2995     642.0
# 2996    1082.0
# 2997     201.0
# 2998      14.0
# 2999     263.0
# Name: total_bedrooms, Length: 3000, dtype: float64

# %% [markdown]
# Con index

# %%
df.total_bedrooms[0]
# Out:
# 661.0

# %% [markdown]
# # **DATASETS** **Library** Y **Pandas**

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 9.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 13.2 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

# %%
dataset = load_dataset("lukebarousse/data_jobs")

# %%
df = dataset['train'].to_pandas()

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %% [markdown]
# **Obtener varias columnas**

# %%
df[['job_title_short', 'job_location']].head(100)
# Out:
#          job_title_short                  job_location
# 0   Senior Data Engineer                 Watertown, CT
# 1           Data Analyst  Guadalajara, Jalisco, Mexico
# 2          Data Engineer               Berlin, Germany
# 3          Data Engineer               San Antonio, TX
# 4          Data Engineer                Washington, DC
# ..                   ...                           ...
# 95         Data Engineer    Mumbai, Maharashtra, India
# 96         Data Engineer                  Torrance, CA
# 97          Data Analyst                United Kingdom
# 98  Senior Data Engineer           Toronto, ON, Canada
# 99         Data Engineer                     Miami, FL
#
# [100 rows x 2 columns]

# %%
df.iloc[90:100]
# Out:
#          job_title_short                                          job_title  \
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...
#
#                   job_location                         job_via  \
# 90                   Australia             via BeBee Australia
# ...

# %%
df[['job_title_short','job_title']].iloc[90:100]
# Out:
#          job_title_short                                          job_title
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_title_short.unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
df[(df.job_title_short == 'Data Analyst') & (df.salary_year_avg.notna())]
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 784033    Data Analyst                     Recruitment Data Analyst
# 784423    Data Analyst                           Sales Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
# 785187    Data Analyst                                 Data Analyst
# 785515    Data Analyst                                 Data Analyst
#
#                        job_location                job_via job_schedule_type  \
# ...

# %%
df.salary_year_avg.notna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: salary_year_avg, Length: 785741, dtype: bool

# %%
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_posted_date.dt.month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
df.sort_values('job_posted_date', inplace=True)

# %%
df
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
df.drop(labels='salary_hour_avg', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 108804 to 90102
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
df.dropna(subset=['salary_year_avg'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %%
df.count()
# Out:
# job_title_short          22003
# job_title                22003
# job_location             21723
# job_via                  22003
# job_schedule_type        21987
# job_work_from_home       22003
# search_location          22003
# job_posted_date          22003
# job_no_degree_mention    22003
# job_health_insurance     22003
# job_country              22003
# salary_rate              22003
# salary_year_avg          22003
# company_name             22003
# job_skills               20170
# job_type_skills          20170
# dtype: int64

# %%
df['salary_year_avg'].median()
# Out:
# 115000.0

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg
# count                          22003     22003.000000
# mean   2023-06-13 01:01:01.813889024    123286.274072
# min              2023-01-01 00:02:56     15000.000000
# 25%       2023-03-17 14:04:49.500000     90000.000000
# 50%              2023-06-11 09:03:27    115000.000000
# 75%              2023-08-26 00:41:15    150000.000000
# max              2023-12-31 23:40:32    960000.000000
# std                              NaN     48312.449482

# %%
df['salary_year_avg'].min()
# Out:
# 15000.0

# %%
min_salary = df['salary_year_avg'].idxmin()

# %%
df.loc[min_salary]
# Out:
# job_title_short                                              Data Engineer
# job_title                                           Data Engineer - Hadoop
# job_location                                                        Brazil
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                     Brazil
# job_posted_date                                        2023-12-09 10:05:30
# job_no_degree_mention                                                 True
# job_health_insurance                                                 False
# job_country                                                         Brazil
# salary_rate                                                           year
# ...

# %%
df['job_title_short'].unique()
# Out:
# array(['Data Scientist', 'Data Engineer', 'Business Analyst',
#        'Data Analyst', 'Senior Data Engineer', 'Senior Data Scientist',
#        'Senior Data Analyst', 'Software Engineer',
#        'Machine Learning Engineer', 'Cloud Engineer'], dtype=object)

# %%
df['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Scientist               5922
# Data Analyst                 5451
# Data Engineer                4500
# Senior Data Scientist        1690
# Senior Data Engineer         1591
# Senior Data Analyst          1131
# Business Analyst              610
# Machine Learning Engineer     576
# Software Engineer             467
# Cloud Engineer                 65
# Name: count, dtype: int64

# %%
df.groupby('job_title_short')

# %%
df.groupby('job_title_short')['salary_year_avg'].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
df.groupby(['job_title_short','job_country'])['salary_year_avg'].median()
# Out:
# job_title_short    job_country
# Business Analyst   Argentina                71100.0
#                    Australia                70000.0
#                    Bangladesh               16500.0
#                    Belgium                  89100.0
#                    Bulgaria                 71925.0
#                                              ...
# Software Engineer  Ukraine                  54000.0
#                    United Arab Emirates     79200.0
#                    United Kingdom           89100.0
#                    United States           130000.0
#                    Vietnam                  53600.0
# Name: salary_year_avg, Length: 598, dtype: float64

# %%
df.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
from datasets import load_dataset

# %%
dataset = load_dataset("lukebarousse/data_jobs")

# %%
df = dataset['train'].to_pandas()

# %%
df.groupby('job_title_short')[['salary_year_avg', 'salary_hour_avg']].agg(['min','max','median'])
# Out:
#                           salary_year_avg                     salary_hour_avg  \
#                                       min       max    median             min
# job_title_short
# Business Analyst                  16500.0  387460.0   85000.0          10.835
# Cloud Engineer                    42000.0  280000.0   90000.0          18.500
# Data Analyst                      25000.0  650000.0   90000.0           8.000
# Data Engineer                     15000.0  525000.0  125000.0           8.000
# Data Scientist                    27000.0  960000.0  127500.0           8.000
# Machine Learning Engineer         30000.0  325000.0  106415.0          10.000
# Senior Data Analyst               30000.0  425000.0  111175.0          13.000
# Senior Data Engineer              35000.0  425000.0  147500.0          12.500
# Senior Data Scientist             45000.0  890000.0  155500.0          17.500
# Software Engineer                 28000.0  375000.0   99150.0          11.000
#
#
# ...

# %% [markdown]
# # ***EJERCICIO PANDAS***

# %%
#Install datasets library
#!pip install datasets #descomentar si hay un aviso de runtime

#Import Libraries
import pandas as pd
from datasets import load_dataset

#Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     206292
# India              51088
# United Kingdom     40375
# France             39922
# Germany            27694
# Spain              25100
# Singapore          23696
# Sudan              21781
# Netherlands        20631
# Italy              17013
# Canada             16029
# Mexico             15139
# Poland             14793
# Portugal           14508
# Australia          12955
# South Africa       12414
# Belgium            12078
# Philippines        11786
# Ireland            11162
# Switzerland         9924
# Name: count, dtype: int64

# %%
us_jobs = df[df['job_country'] == "United States"]

# %%
us_jobs = us_jobs[us_jobs['salary_year_avg'].notna()]

us_jobs
# Out:
#        job_title_short                                          job_title  \
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# 116     Data Scientist                                     Data Scientist
# 146      Data Engineer  Data Engineer Graduate (Real Time Communicatio...
# ...                ...                                                ...
# 785563  Data Scientist  Data Scientist I/II (Model Risk Management & M...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#              job_location                                    job_via  \
# ...

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].min()
# Out:
# job_title_short
# Business Analyst             35000.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                23496.0
# Data Scientist               30000.0
# Machine Learning Engineer    44408.5
# Senior Data Analyst          35360.0
# Senior Data Engineer         45000.0
# Senior Data Scientist        55000.0
# Software Engineer            48982.0
# Name: salary_year_avg, dtype: float64

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median', 'min', 'max', 'count']).sort_values(by= 'median')
# Out:
#                              median      min       max  count
# job_title_short
# Business Analyst            90000.0  35000.0  387460.0    431
# Data Analyst                90000.0  25000.0  375000.0   4350
# Senior Data Analyst        110000.0  35360.0  425000.0    913
# Cloud Engineer             116100.0  42000.0  221844.0     20
# Data Engineer              125000.0  23496.0  525000.0   2915
# Data Scientist             130000.0  30000.0  960000.0   4553
# Software Engineer          130000.0  48982.0  375000.0    157
# Machine Learning Engineer  150000.0  44408.5  315000.0    128
# Senior Data Engineer       150000.0  45000.0  375000.0   1058
# Senior Data Scientist      155000.0  55000.0  475000.0   1241

# %% [markdown]
# # ***MATPLOTLIB***

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 5 ,0.1)
y= np.sin(x)
plt.plot(x,y)

# %%
x = [1,2,3,4]
y = [1,2,3,4]

plt.plot(x,y)
plt.show()

# %%
df.job_posted_date.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-7c1d84a40952> in <cell line: 0>()
# ----> 1 df.job_posted_date.head()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'job_posted_date'

# %%
plt.plot(df.job_posted_date,df.job_posted_date)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-f57ff5b92aa5> in <cell line: 0>()
# ----> 1 plt.plot(df.job_posted_date,df.job_posted_date)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'job_posted_date'

# %% [markdown]
# # ***Ejercicio Matplotlib***

# %%
# !pip install datasets
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 14.2 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# data_jobs.csv:   0%|          | 0.00/231M [00:00<?, ?B/s]
# ...

# %%
job_salary = df.groupby('job_title_short')['salary_year_avg'].median().sort_values()

# %%
job_salary.plot(kind= 'barh')
plt.xlabel('Salary ($USD)')
plt.ylabel('')
plt.title('Median Salary by Job Title')
plt.show()
